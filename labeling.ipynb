# %%
import pandas as pd
import numpy as np

# %%
m2dls = {
    "Locomotion": [1, 2, 3, 4, 6, 7, 48, 54, 57, 58],
    "Exploration": [25, 27, 28, 20, 10, 49],
    "Left Turn": [8],
    "Right Turn": [9],
    "Grooming": [16, 17, 19, 33, 59],
    "Sniffing": [5, 26, 31, 35, 53],
    "Rearing": [12, 13, 56, 30, 34, 37, 50, 55],
    "Light Climbing": [42, 43],
    "Climbing": [29, 32, 14, 22, 40, 64],
    "Light Descent": [24, 36, 38, 39, 45, 46],
    "Descent": [51, 11],
    "Look Over": [15, 41, 44, 47, 63],
    "Pause": [52, 60, 61, 62], 
    "Other": [18, 21, 23]
}

# %%
m7dms = {
    "Locomotion": [3, 9, 19, 34],
    "Exploration": [7, 10, 26, 39, 48, 62],
    "Left Turn": [],
    "Right Turn": [],
    "Grooming": [35, 36, 44, 47, 59],
    "Sniffing": [1, 12, 25, 31, 33, 42, 51],
    "Rearing": [2, 11, 20, 23, 24, 54, 57],
    "Light Climbing": [],
    "Climbing": [5, 29],
    "Stretch": [4, 30],
    "Light Descent": [8],
    "Descent": [16, 60, 61],
    "Look Over": [18, 53, 63],
    "Pause": [37, 38, 58], 
    "Other": [6, 45, 52],
    "combination": {
        "Sniffing+Climbing": [13, 49, 50, 55, 21],
        "Locomotion+Climbing": [22, 32],
        "Locomotion+Grooming": [17, 41],
        "Grooming+Descent": [15, 28, 56, 14, 27],
        "Grooming+Look Over": [46],
        "Grooming+Back up": [40],
        "Pause+Climbing": [43],
    }
}

# %%
m5dms = {
    "Locomotion": [1, 2, 3, 11, 12, 13, 15, 16, 20, 21, 22, 39, 44, 45, 50, 57, 62],
    "Exploration": [5, 6, 19, 28, 30, 35, 37, 38, 41, 54],
    "Grooming": [32, 34, 40, 48,  53],
    "Sniffing": [4, 7, 17, 18, 26, 31, 60],
    "Rearing": [24, 36, 42 ],
    "Light Climbing": [23, 14, 46],
    "Climbing": [8, 10, 43],
    "Light Descent": [25],
    "Descent": [9],
    "Look Over": [],
    "Pause": [27, 29, 34, 51, 52],
    "Light Climbing/Descent + Grooming": [47, 49, 61],
    "Exploration + Sniffing": [55, 56, 63],
    "Exploration + Rearing": [58, 59],
    "Other": [],
}
